# %%
r = open('additional.txt', 'r')
w = open('additional_overlap_removed.txt', 'w')

# %%
blacklist = ['DJI_0003_001-007',
            'DJI_0004_001-008',
            'DJI_0003_002',
            'DJI_0006_003',
            'DJI_0009_001',
            'DJI_0011_002',
            'DJI_0006_001-011',
            'DJI_0007_001-005',
            'DJI_0001_001-002_00601',
            'DJI_0001_002-014',
            'DJI_0007_002',
            'DJI_0002_001-015',
            'DJI_0006_002-012',
            'DJI_0004_003',
            'DJI_0002_002',
            'DJI_0004_002-009']

# %%
lines =r.readlines()
for line in lines:
    flag = False
    for item in blacklist:
        if item in line:
            print(line)            
            flag = True
    if not flag:
        w.write(line)
f.close()
w.close()
# Out:
# total_20220724_20220818_update_generated/Empty/empty4044_DJI_0003_002.jpg 0
#
# total_20220724_20220818_update_generated/Empty/empty3890_DJI_0002_002.jpg 0
#
# total_20220724_20220818_update_generated/Empty/empty1176_DJI_0007_002.jpg 0
#
# total_20220724_20220818_update_generated/Occupied/occupied2384_DJI_0002_002.jpg 1
#
# total_20220724_20220818_update_generated/Empty/empty1842_DJI_0003_002.jpg 0
#
# total_20220724_20220818_update_generated/Occupied/occupied2868_DJI_0002_001-015.jpg 1
#
# total_20220724_20220818_update_generated/Occupied/occupied839_DJI_0004_003.jpg 1
#
# total_20220724_20220818_update_generated/Occupied/occupied2204_DJI_0007_002.jpg 1
#
# total_20220724_20220818_update_generated/Occupied/occupied6495_DJI_0002_002.jpg 1
#
# total_20220724_20220818_update_generated/Empty/empty2390_DJI_0006_003.jpg 0
#
# total_20220724_20220818_update_generated/Occupied/occupied6489_DJI_0002_002.jpg 1
#
# ...
